# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
customer_df=pd.read_csv(r"C:\Users\saran\Desktop\Project 2\Customer_churn.csv")
zipcode_df=pd.read_csv(r"C:\Users\saran\Desktop\Project 2\Zipcode_population.csv")

# %%
customer_df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %%
zipcode_df.head()
# Out:
#    Zip Code  Population
# 0     90001       54492
# 1     90002       44586
# 2     90003       58198
# 3     90004       67852
# 4     90005       43019

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %%
zipcode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Zip Code    1671 non-null   int64
#  1   Population  1671 non-null   int64
# dtypes: int64(2)
# memory usage: 26.2 KB

# %%
# Merging Databases
merge_df=pd.merge(customer_df,zipcode_df,on="Zip Code", how="left")

# %%
merge_df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...  Monthly Charge  \
# 0     93225  34.827662 -118.999073                    2  ...            65.6
# 1     91206  34.162515 -118.203869                    0  ...            -4.0
# 2     92627  33.645672 -117.922613                    0  ...            73.9
# 3     94553  38.014457 -122.115432                    1  ...            98.0
# 4     93010  34.227846 -119.079903                    3  ...            83.9
#
#   Total Charges Total Refunds  Total Extra Data Charges  \
# ...

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 39 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %% [markdown]
# # Basic Statistical Summary

# %%
merge_df.describe()
# Out:
#                Age  Number of Dependents      Zip Code     Latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          Longitude  Number of Referrals  Tenure in Months  \
# count  7043.000000          7043.000000       7043.000000
# mean   -119.756684             1.951867         32.386767
# std       2.154425             3.001199         24.542061
# min    -124.301372             0.000000          1.000000
# 25%    -121.788090             0.000000          9.000000
# ...

# %% [markdown]
# # Churn Rate Overview

# %%
# Churn Rate
churn_rate=merge_df["Customer Status"].value_counts(normalize=True)*100
print(churn_rate)
# Out:
# Customer Status
# Stayed     67.016896
# Churned    26.536987
# Joined      6.446117
# Name: proportion, dtype: float64

# %%
# Churn Rate by City
churn_rate_city=merge_df[merge_df["Customer Status"]=="Churned"].groupby("City").size().sort_values(ascending=False)
print(churn_rate_city.head(10))
# Out:
# City
# San Diego        185
# Los Angeles       78
# San Francisco     31
# San Jose          29
# Fallbrook         26
# Sacramento        26
# Temecula          22
# Escondido         16
# Long Beach        15
# Oakland           13
# dtype: int64

# %%
# Churn Rate by Internet Type
churn_rate_it=merge_df.groupby("Internet Type")["Customer Status"].value_counts(normalize=True).unstack().fillna(0)*100
print(churn_rate_it)
# Out:
# Customer Status    Churned    Joined     Stayed
# Internet Type
# Cable            25.662651  6.746988  67.590361
# DSL              18.583535  6.961259  74.455206
# Fiber Optic      40.724876  3.327842  55.947282

# %%
# Churn Rate by Age Group
def get_age_group(age):
    if age<30:
        return '<30'
    elif 30<= age<50:
        return '30-50'
    elif 50<= age< 70:
        return '50-70'
    else:
        return '70+'
merge_df["Age Group"] = merge_df["Age"].apply(get_age_group)
churn_by_age=merge_df[merge_df["Customer Status"]=="Churned"]["Age Group"].value_counts().sort_index()
print(churn_by_age)
# Out:
# Age Group
# 30-50    627
# 50-70    614
# 70+      324
# <30      304
# Name: count, dtype: int64

# %%
# Churn Rate by Contract Type
churn_by_contract=merge_df.groupby("Contract")["Customer Status"].value_counts(normalize=True).unstack().fillna(0)*100
print(churn_by_contract)
# Out:
# Customer Status    Churned     Joined     Stayed
# Contract
# Month-to-Month   45.844875  11.301939  42.853186
# One Year         10.709677   1.548387  87.741935
# Two Year          2.549124   1.168348  96.282528

# %%
# Correlation with Revenue
merge_df.groupby("Customer Status")["Total Revenue"].mean()
# Out:
# Customer Status
# Churned    1971.353569
# Joined      119.558921
# Stayed     3735.676297
# Name: Total Revenue, dtype: float64

# %% [markdown]
# # Visualisation

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x=churn_by_age.index, y=churn_by_age.values, palette="Set2")
plt.title('Churned Customers by Age Group', fontsize=14)
plt.xlabel('Age Group')
plt.ylabel('Number of Churned Customers')
plt.grid(axis='y', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Churn Rate by Internet Type [Visualisation]

# %%
churn_by_internet = merge_df.groupby('Internet Type').apply(
    lambda x: (x['Customer Status'] == 'Churned').sum() * 100 / len(x)
).reset_index(name='Churn Rate')

# %%
plt.figure(figsize=(6, 5))
sns.barplot(data=churn_by_internet, x='Internet Type', y='Churn Rate', palette='pastel')
plt.title('Churn Rate by Internet Type', fontsize=14)
plt.xlabel('Internet Type')
plt.ylabel('Churn Rate (%)')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Customer Status Distribution

# %%
status_counts = merge_df['Customer Status'].value_counts()

# %%
plt.figure(figsize=(5, 5))
colors = ['#FF9999','#66B3FF','#99FF99']
status_counts.plot.pie(
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors, 
    shadow=True,
    explode=(0.05, 0.05, 0.05)  
)
plt.title('Customer Status Distribution', fontsize=14)
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top 10 key churn reasons of customer

# %%
churn_rsn=merge_df["Churn Reason"].value_counts().head(10)

# %%
plt.figure(figsize=(7,7))
churn_rsn.plot.pie(
    autopct='%1.1f%%'
)
plt.title("Top 10 key churn reasons",fontsize=14)
plt.ylabel("")
plt.tight_layout()
plt.show()
